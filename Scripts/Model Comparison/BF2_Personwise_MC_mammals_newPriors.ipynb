# %% [markdown]
# # BayesFlow: Personwise Model Comparison (Mammals)
#
# Author:      David Izydorczyk

# %% [markdown]
# Reminder: Install new packages with `python3.11 -m pip install package`  | active environemnt `.\personwise_BF\Scripts\activate`

# %%
import numpy as np
import numpy.random as rng


import matplotlib.pyplot as plt
import seaborn as sns


import os
if "KERAS_BACKEND" not in os.environ:
    # set this to "torch", "tensorflow", or "jax"
    os.environ["KERAS_BACKEND"] = "jax"

import keras
import bayesflow as bf
import pandas as pd
import statsmodels.formula.api as sm



from plotnine import (
    theme_set,
    theme_bw
)
theme_set(theme_bw())
# Out:
# INFO:bayesflow:Using backend 'jax'

# %%
import utils.helper_functions as fn
import utils.model_functions as mf

# makes sure mf is loaded correctly
import importlib
importlib.reload(mf) 
importlib.reload(fn)
# Out:
# <module 'utils.helper_functions' from 'c:\\Users\\dizydorc\\OneDrive\\University\\Project Github Repositories\\Estimation processes in real-world domains\\Scripts\\Model Comparison\\utils\\helper_functions.py'>

# %%
# avoid scientific notation for outputs
np.set_printoptions(suppress=True)

# %% [markdown]
# # 1 Load Design Data

# %%
df = pd.read_csv('..\..\Materials\design_data_mammals.csv', sep=';',decimal=",")
df.head()
# Out:
#    ID             item  crit     img  training     dim_1     dim_2     dim_3  \
# 0   1           Aoudad   335  01.png         0 -0.567875 -0.015278  0.216645
# 1   2  Brazilian tapir  1095  02.png         0 -0.392465  0.184646 -0.071257
# 2   3   American bison   912  03.png         0 -0.553953 -0.067230  0.094129
# 3   4   Giant anteater  1186  04.png         0  0.067508  0.169333 -0.082213
# 4   5             Ibex   797  05.png         0 -0.557179  0.020041  0.214498
#
#       dim_4     dim_5     dim_6     dim_7     dim_8     dim_9    dim_10
# 0 -0.260836 -0.047524 -0.193240  0.043678 -0.002896 -0.120112  0.076603
# 1 -0.027939  0.298438 -0.240948 -0.174659 -0.244244  0.003726 -0.023815
# 2 -0.232337  0.206952  0.030337  0.129310  0.098340 -0.205172  0.202011
# 3  0.037893  0.284212 -0.473084 -0.060646 -0.019342  0.346182 -0.129704
# 4 -0.259488 -0.106287 -0.071999 -0.062104 -0.004846 -0.196821  0.151096

# %%
all_cues = df[[f'dim_{i}' for i in range(1, 11)]].to_numpy(dtype=float)
all_crit = df[['crit']].to_numpy(dtype=float).flatten()

# Get Exemplar Set 
exemplars = df.loc[df['training'] == 1,:] 
ex_cues   = exemplars[[f'dim_{i}' for i in range(1, 11)]].to_numpy(dtype=float)
ex_crit   = exemplars[['crit']].to_numpy(dtype=float).flatten()
ex_IDs    = exemplars[["ID"]].to_numpy(dtype=float).squeeze().astype(int)

# Get Data from only Testing items
testing = df.loc[df['training'] == 0,:]

# Get the IDs
test_IDs = testing[["ID"]].to_numpy(dtype=float).squeeze().astype(int)

# Extract cues of the testing stimuli
cues     = testing[[f'dim_{i}' for i in range(1, 11)]].to_numpy(dtype=float)

# Make cue dictionary
dict_cues = {f"cue_{i}": cues[:, i] for i in range(cues.shape[1])}

# Geet number of trials and number of dimensions
n_trials, n_dim     = cues.shape

print("n_trials:", n_trials)
print("n_dim:"   , n_dim)
# Out:
# n_trials: 68
# n_dim: 10

# %%
# Set general parameters
rate = 1/800 # 0.01

# %%
# Define positional encodings
position_encodings = np.linspace(0, 1, n_trials, dtype=np.float32)

# %% [markdown]
# # 2 Define Models

# %% [markdown]
# ## 2.1 CAM - Cue Abstraction (Rule) Model

# %%
# Run Regression on whole item samples
result = sm.ols(formula="crit ~ dim_1 + dim_2 + dim_3 + dim_4 + dim_5 + dim_6 + dim_7 + dim_8 + dim_9 + dim_10", data=df).fit()
# print(result.params)
# print(result.summary())

# %%
def prior_CAM(n_dim = n_dim, rate = rate):

    # Init weight parameters
    w = np.zeros(n_dim+1)

    # Intercept
    w[0]   = rng.normal(984.65, 300)

    # Dimension weights (Importance)
    w[1:]  = rng.normal(0, 1500, size = n_dim)

    sigma  = rng.exponential(1/rate)

    return dict(w=w, sigma=sigma)

# %%
def model_CAM(w, sigma, cues=cues, p=position_encodings):

    n_trials, _   = cues.shape
  
    # Pre-allocate the output matrix
    pred_crit = mf.CAM_experiment(w,cues)

    # Simulate responses 
    x = fn.truncnorm_r(mean=pred_crit, sd=sigma, low=0, upp=10000, size=n_trials)
    
    return dict(x=x, p=p)

# %%
simulator_CAM = bf.make_simulator([prior_CAM, model_CAM])

# %%
fig, ax = fn.plot_prior_predictives(simulator_CAM, "CAM")

# %% [markdown]
# ## 2.2 GCM - Exemplar Model

# %%
def prior_GCM(n_dim = n_dim, rate = rate):

    c      = rng.exponential(1/0.1)
    w      = rng.dirichlet(np.ones(n_dim), size = 1)*n_dim
    sigma  = rng.exponential(1/rate)

    return dict(c=c, w=w.squeeze(), sigma=sigma)

# %%
def model_GCM(c, w, sigma, cues=cues, ex_cues=ex_cues, ex_crit=ex_crit, p=position_encodings):
  
    n_trials = cues.shape[0]

    # Make predictions based on the GCM model for all trials at once
    pred_crit = mf.GCM_experiment(cues, ex_cues, ex_crit, w, c)

    # Simulate responses
    x = fn.truncnorm_r(mean=pred_crit, sd=sigma, low=0, upp=10000, size=n_trials)

    return dict(x=x, p=p)

# %%
simulator_GCM = bf.make_simulator([prior_GCM, model_GCM])

# %%
fig, ax = fn.plot_prior_predictives(simulator_GCM, "GCM")

# %% [markdown]
# ## 2.3 RulExJ Model

# %%
def prior_RULEXJ(n_dim = n_dim, rate = rate):

    # Rule part
    CAM_pars = prior_CAM(n_dim = n_dim, rate = rate)

    # Exemplar part
    GCM_pars = prior_GCM(n_dim = n_dim, rate = rate)

    # Blending
    a        = rng.uniform(0,1)

    return dict(alpha = a, w_CAM=CAM_pars["w"], c = GCM_pars["c"], w_GCM = GCM_pars["w"], sigma=CAM_pars["sigma"])

# %%
def model_RULEXJ(alpha, w_CAM, c, w_GCM, sigma,  cues=cues, ex_cues=ex_cues, ex_crit=ex_crit, p=position_encodings):
    
    n_trials, _   = cues.shape
    
    pred_CAM = mf.CAM_experiment(w_CAM,cues)

    pred_GCM = mf.GCM_experiment(cues, ex_cues, ex_crit,w_GCM,c)

    pred_RULEXJ = alpha*pred_CAM + (1-alpha)*pred_GCM

    # Simulate responses 
    x = fn.truncnorm_r(mean=pred_RULEXJ, sd=sigma, low=0, upp=10000, size=n_trials)

    return dict(x=x, p=p)

# %%
simulator_RULEXJ = bf.make_simulator([prior_RULEXJ, model_RULEXJ])

# %%
fig, ax = fn.plot_prior_predictives(simulator_RULEXJ, "RulExJ")

# %% [markdown]
# ## 2.4 Mapping Model (MAPP)

# %% [markdown]
# For the mapping model, the direction of the cues have to coded so that each cue (i.e., dimension) has a positive relationship with the criterion.

# %%
# Change cue direction and redefine exemplar and stimuli cues for the mapping model
all_mapp_cues  = mf.preprocess_cues(all_cues,all_crit)
ex_mapp_cues   = all_mapp_cues[ex_IDs-1,:]
mapp_cues      = all_mapp_cues[test_IDs-1,:]
dict_mapp_cues = {f"cue_{i}": mapp_cues[:, i] for i in range(mapp_cues.shape[1])}

# %%
def prior_MAPP(lower = 2, upper = 12, rate = rate):

    n_cats = fn.truncated_poisson_np(5, lower = lower, upper = upper)
    sigma  = rng.exponential(1/rate)
    
    return  dict(n_cats=n_cats[0], sigma=sigma)

# %%
def model_MAPP(n_cats, sigma, cues=mapp_cues,ex_cues=ex_mapp_cues, ex_crit=ex_crit, p=position_encodings):

    n_trials, _   =  cues.shape 

    # Make predictions based on the GCM model for each person
    pred_crit = mf.MAPP_experiment(n_cats,cues,ex_cues,ex_crit)

    # Simulate responses 
    x = fn.truncnorm_r(mean=pred_crit, sd=sigma, low=0, upp=10000, size=n_trials)
  

    return dict(x=x, p=p)

# %%
simulator_MAPP = bf.make_simulator([prior_MAPP, model_MAPP])

# %%
fig, ax = fn.plot_prior_predictives(simulator_MAPP, "Mapping")

# %% [markdown]
# ## 2.5 QuickEst

# %% [markdown]
# For the QuickEst-Model, the direction of the cues have to coded so that each cue (i.e., dimension) has a positive relationship with the criterion. Also the cues need to binary.

# %%
# Change cue direction and redefine exemplar and stimuli cues for the QuickEst model
all_QEst_cues  = mf.preprocess_cues_QuickEst(all_cues,all_crit)
ex_QEst_cues   = all_QEst_cues[ex_IDs-1,:]
QEst_cues      = all_QEst_cues[test_IDs-1,:]
dict_QEst_cues = {f"cue_{i}": QEst_cues[:, i] for i in range(QEst_cues.shape[1])}

# %%
def prior_QEst():

    sigma = fn.truncated_cauchy_np(loc=0, scale=100, lower=0.001, upper=1000, size=1)

    return dict(sigma=sigma)

# %%
def model_QEst(sigma,  cues = QEst_cues, ex_cues = ex_QEst_cues, ex_crit = ex_crit, p=position_encodings):
 
    # Step 0: Draw "memorized" ex_crit for each participant
    mem_ex_crit = np.random.normal(ex_crit,sigma) 

    # Make predictions based on the GCM model for each person
    x = mf.QuickEst_experiment(cues,ex_cues,mem_ex_crit)
 

    return dict(x = np.clip(x, 0, 10000), p=p)

# %%
simulator_QEst = bf.make_simulator([prior_QEst, model_QEst])

# %%
fig, ax = fn.plot_prior_predictives(simulator_QEst, "QuickEst")

# %% [markdown]
# ## 2.6 RGuess - Random Guessing

# %%
def prior_RGuess():

    sigma_range = rng.exponential(1/0.01, size = 1)

    return  dict(sigma_range=sigma_range)

# %%
def model_RGuess(sigma_range, cues = cues, ex_crit = ex_crit, p=position_encodings):

    n_trials, _   =  cues.shape 

    min_observed_crit = rng.normal(np.min(ex_crit),sigma_range)
    range_width = max(0.01, rng.normal(np.max(ex_crit) - np.min(ex_crit), sigma_range))  # enforce positive width

    max_observed_crit = min_observed_crit + abs(range_width)

    x =  rng.uniform(min_observed_crit, max_observed_crit, size = n_trials)
    
    return dict(x = np.clip(x, 0, 10000), p=p)

# %%
simulator_RGuess = bf.make_simulator([prior_RGuess, model_RGuess])

# %%
fig, ax = fn.plot_prior_predictives(simulator_RGuess, "Random Guessing")

# %% [markdown]
# # 3 Training Networks

# %%
simulator = bf.simulators.ModelComparisonSimulator(
    simulators        = [simulator_RULEXJ,simulator_CAM,simulator_GCM,simulator_MAPP,simulator_QEst,simulator_RGuess],
    use_mixed_batches = True
)

# %%
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")   
    .as_time_series(["x","p"])
    .standardize("x")
    .drop(["alpha","c","sigma","w_GCM","w_CAM","n_cats","sigma_range"])
    .concatenate(["x", "p"], into="summary_variables")
)

summary_network    = bf.networks.TimeSeriesNetwork(summary_dim=20)

classifier_network = bf.networks.MLP(widths=[256] * 32, activation="silu", dropout=None)

approximator = bf.approximators.ModelComparisonApproximator(
     num_models         = 6,
     classifier_network = classifier_network,
     summary_network    = summary_network,
     adapter            = adapter,
 )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 12
#       1 adapter = (
#       2     bf.adapters.Adapter()
#       3     .convert_dtype("float64", "float32")
#    (...)      7     .concatenate(["x", "p"], into="summary_variables")
#       8 )
#      10 summary_network    = bf.networks.TimeSeriesNetwork(summary_dim=20)
# ---> 12 classifier_network = bf.networks.MLP(widths=[256] * 32, activation="silu", dropout=None)
#      14 approximator = bf.approximators.ModelComparisonApproximator(
#      15      num_models         = 6,
#      16      classifier_network = classifier_network,
#      17      summary_network    = summary_network,
#      18      adapter            = adapter,
#      19  )
#
# File c:\Users\dizydorc\OneDrive\University\Project Github Repositories\Estimation processes in real-world domains\.venv\Lib\site-packages\bayesflow\networks\mlp\mlp.py:73, in MLP.__init__(self, widths, activation, kernel_initializer, residual, dropout, norm, spectral_normalization, **kwargs)
#      70 layers = []
#      72 for width in widths:
# ---> 73     layer = self._make_layer(
#      74         width, activation, kernel_initializer, residual, dropout, norm, spectral_normalization
#      75     )
#      76     layers.append(layer)
#      78 super().__init__(layers, **sequential_kwargs(kwargs))
#
# File c:\Users\dizydorc\OneDrive\University\Project Github Repositories\Estimation processes in real-world domains\.venv\Lib\site-packages\bayesflow\networks\mlp\mlp.py:149, in MLP._make_layer(width, activation, kernel_initializer, residual, dropout, norm, spectral_normalization)
#     146     raise TypeError(f"Cannot infer norm from {norm!r} of type {type(norm)}.")
#     148 if residual:
# --> 149     return Residual(*layers)
#     151 return keras.Sequential(layers)
#
# File c:\Users\dizydorc\OneDrive\University\Project Github Repositories\Estimation processes in real-world domains\.venv\Lib\site-packages\bayesflow\networks\residual\residual.py:16, in Residual.__init__(self, *layers, **kwargs)
#      14     layers = layers[0]
#      15 super().__init__(list(layers), **sequential_kwargs(kwargs))
# ---> 16 self.projector = keras.layers.Dense(units=None, name="projector")
#
# File c:\Users\dizydorc\OneDrive\University\Project Github Repositories\Estimation processes in real-world domains\.venv\Lib\site-packages\keras\src\layers\core\dense.py:102, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, lora_rank, lora_alpha, quantization_config, **kwargs)
#      84 def __init__(
#      85     self,
#      86     units,
#    (...)     99     **kwargs,
#     100 ):
#     101     if not isinstance(units, int) or units <= 0:
# --> 102         raise ValueError(
#     103             "Received an invalid value for `units`, expected a positive "
#     104             f"integer. Received: units={units}"
#     105         )
#     107     super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#     108     self.units = units
#
# ValueError: Received an invalid value for `units`, expected a positive integer. Received: units=None

# %%
num_batches_per_epoch = 512
batch_size            = 64
epochs                = 100

learning_rate = keras.optimizers.schedules.CosineDecay(1e-4, decay_steps=epochs * num_batches_per_epoch)
optimizer     = keras.optimizers.Adam(learning_rate=learning_rate)
approximator.compile(optimizer=optimizer)

# %%
# %%time

history = approximator.fit(epochs = epochs, batch_size = batch_size,  num_batches = num_batches_per_epoch, adapter = adapter, simulator = simulator)
# Out:
# INFO:bayesflow:Building dataset from simulator instance of ModelComparisonSimulator.
# INFO:bayesflow:Using 16 data loading workers.
# INFO:bayesflow:Building on a test batch.
# INFO:bayesflow:Incompatible simulator output. The following keys will be dropped: alpha, c, n_cats, sigma, sigma_range, w, w_CAM, w_GCM.
# Epoch 1/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 47ms/step - loss: 20.3632 - loss/classifier_loss: 20.3632
# Epoch 2/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - loss: 2.5486 - loss/classifier_loss: 2.5486
# Epoch 3/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - loss: 1.2135 - loss/classifier_loss: 1.2135
# Epoch 4/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - loss: 0.7824 - loss/classifier_loss: 0.7824
# Epoch 5/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - loss: 0.6310 - loss/classifier_loss: 0.6310
# Epoch 6/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - loss: 0.5460 - loss/classifier_loss: 0.5460
# Epoch 7/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 47ms/step - loss: 0.5130 - loss/classifier_loss: 0.5130
# Epoch 8/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.5048 - loss/classifier_loss: 0.5048
# Epoch 9/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.4444 - loss/classifier_loss: 0.4444
# Epoch 10/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.4221 - loss/classifier_loss: 0.4221
# Epoch 11/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.4469 - loss/classifier_loss: 0.4469
# Epoch 12/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.4172 - loss/classifier_loss: 0.4172
# Epoch 13/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3957 - loss/classifier_loss: 0.3957
# Epoch 14/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3961 - loss/classifier_loss: 0.3961
# Epoch 15/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3906 - loss/classifier_loss: 0.3906
# Epoch 16/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3518 - loss/classifier_loss: 0.3518
# Epoch 17/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3716 - loss/classifier_loss: 0.3716
# Epoch 18/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3486 - loss/classifier_loss: 0.3486
# Epoch 19/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3393 - loss/classifier_loss: 0.3393
# Epoch 20/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3707 - loss/classifier_loss: 0.3707
# Epoch 21/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 55ms/step - loss: 0.3229 - loss/classifier_loss: 0.3229
# Epoch 22/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - loss: 0.3254 - loss/classifier_loss: 0.3254
# Epoch 23/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3104 - loss/classifier_loss: 0.3104
# Epoch 24/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 49ms/step - loss: 0.3291 - loss/classifier_loss: 0.3291
# Epoch 25/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 49ms/step - loss: 0.3085 - loss/classifier_loss: 0.3085
# Epoch 26/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 29s 55ms/step - loss: 0.2927 - loss/classifier_loss: 0.2927
# Epoch 27/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 51ms/step - loss: 0.2916 - loss/classifier_loss: 0.2916
# Epoch 28/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2880 - loss/classifier_loss: 0.2880
# Epoch 29/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.3723 - loss/classifier_loss: 0.3723
# Epoch 30/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2820 - loss/classifier_loss: 0.2820
# Epoch 31/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2740 - loss/classifier_loss: 0.2740
# Epoch 32/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 0.2717 - loss/classifier_loss: 0.2717
# Epoch 33/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2656 - loss/classifier_loss: 0.2656
# Epoch 34/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2692 - loss/classifier_loss: 0.2692
# Epoch 35/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - loss: 0.2677 - loss/classifier_loss: 0.2677
# Epoch 36/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2806 - loss/classifier_loss: 0.2806
# Epoch 37/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - loss: 0.2615 - loss/classifier_loss: 0.2615
# Epoch 38/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2702 - loss/classifier_loss: 0.2702
# Epoch 39/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2588 - loss/classifier_loss: 0.2588
# Epoch 40/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 0.2659 - loss/classifier_loss: 0.2659
# Epoch 41/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2566 - loss/classifier_loss: 0.2566
# Epoch 42/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 49ms/step - loss: 0.2517 - loss/classifier_loss: 0.2517
# Epoch 43/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2503 - loss/classifier_loss: 0.2503
# Epoch 44/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2470 - loss/classifier_loss: 0.2470
# Epoch 45/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step - loss: 0.2518 - loss/classifier_loss: 0.2518
# Epoch 46/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - loss: 0.2445 - loss/classifier_loss: 0.2445
# Epoch 47/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2434 - loss/classifier_loss: 0.2434
# Epoch 48/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2448 - loss/classifier_loss: 0.2448
# Epoch 49/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2426 - loss/classifier_loss: 0.2426
# Epoch 50/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - loss: 0.2387 - loss/classifier_loss: 0.2387
# Epoch 51/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2362 - loss/classifier_loss: 0.2362
# Epoch 52/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2333 - loss/classifier_loss: 0.2333
# Epoch 53/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2356 - loss/classifier_loss: 0.2356
# Epoch 54/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 52ms/step - loss: 0.2300 - loss/classifier_loss: 0.2300
# Epoch 55/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2351 - loss/classifier_loss: 0.2351
# Epoch 56/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2353 - loss/classifier_loss: 0.2353
# Epoch 57/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - loss: 0.2285 - loss/classifier_loss: 0.2285
# Epoch 58/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2242 - loss/classifier_loss: 0.2242
# Epoch 59/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2298 - loss/classifier_loss: 0.2298
# Epoch 60/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2279 - loss/classifier_loss: 0.2279
# Epoch 61/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2283 - loss/classifier_loss: 0.2283
# Epoch 62/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2147 - loss/classifier_loss: 0.2147
# Epoch 63/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 49ms/step - loss: 0.2270 - loss/classifier_loss: 0.2270
# Epoch 64/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2228 - loss/classifier_loss: 0.2228
# Epoch 65/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 52ms/step - loss: 0.2166 - loss/classifier_loss: 0.2166
# Epoch 66/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2169 - loss/classifier_loss: 0.2169
# Epoch 67/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - loss: 0.2179 - loss/classifier_loss: 0.2179
# Epoch 68/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2145 - loss/classifier_loss: 0.2145
# Epoch 69/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 0.2179 - loss/classifier_loss: 0.2179
# Epoch 70/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step - loss: 0.2092 - loss/classifier_loss: 0.2092
# Epoch 71/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - loss: 0.2121 - loss/classifier_loss: 0.2121
# Epoch 72/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2089 - loss/classifier_loss: 0.2089
# Epoch 73/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 52ms/step - loss: 0.2133 - loss/classifier_loss: 0.2133
# Epoch 74/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2077 - loss/classifier_loss: 0.2077
# Epoch 75/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 49ms/step - loss: 0.2079 - loss/classifier_loss: 0.2079
# Epoch 76/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2083 - loss/classifier_loss: 0.2083
# Epoch 77/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step - loss: 0.2112 - loss/classifier_loss: 0.2112
# Epoch 78/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.2053 - loss/classifier_loss: 0.2053
# Epoch 79/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 49ms/step - loss: 0.2062 - loss/classifier_loss: 0.2062
# Epoch 80/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2015 - loss/classifier_loss: 0.2015
# Epoch 81/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - loss: 0.1998 - loss/classifier_loss: 0.1998
# Epoch 82/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step - loss: 0.2041 - loss/classifier_loss: 0.2041
# Epoch 83/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 49ms/step - loss: 0.2066 - loss/classifier_loss: 0.2066
# Epoch 84/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 49ms/step - loss: 0.1962 - loss/classifier_loss: 0.1962
# Epoch 85/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step - loss: 0.2030 - loss/classifier_loss: 0.2030
# Epoch 86/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 52ms/step - loss: 0.1999 - loss/classifier_loss: 0.1999
# Epoch 87/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2010 - loss/classifier_loss: 0.2010
# Epoch 88/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - loss: 0.1957 - loss/classifier_loss: 0.1957
# Epoch 89/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step - loss: 0.1972 - loss/classifier_loss: 0.1972
# Epoch 90/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 0.2058 - loss/classifier_loss: 0.2058
# Epoch 91/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.2004 - loss/classifier_loss: 0.2004
# Epoch 92/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 0.1977 - loss/classifier_loss: 0.1977
# Epoch 93/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - loss: 0.1990 - loss/classifier_loss: 0.1990
# Epoch 94/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 51ms/step - loss: 0.1965 - loss/classifier_loss: 0.1965
# Epoch 95/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.1978 - loss/classifier_loss: 0.1978
# Epoch 96/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 51ms/step - loss: 0.1999 - loss/classifier_loss: 0.1999
# Epoch 97/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 29s 55ms/step - loss: 0.1950 - loss/classifier_loss: 0.1950
# Epoch 98/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 27s 52ms/step - loss: 0.1909 - loss/classifier_loss: 0.1909
# Epoch 99/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - loss: 0.1930 - loss/classifier_loss: 0.1930
# Epoch 100/100
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 26s 51ms/step - loss: 0.1964 - loss/classifier_loss: 0.1964
# CPU times: total: 2h 19min 23s
# Wall time: 43min 31s

# %%
df          = simulator.sample(10000)
pred_models = approximator.predict(conditions=df)

# %%
f=bf.diagnostics.plots.mc_confusion_matrix(
    pred_models=pred_models,
    true_models=df["model_indices"],
    normalize="true",
    model_names=["   RULEXJ   ", "   CAM   ", "   GCM   ", "   MAPP   ", "   QEst   ", "   RGuess   "]
)

# %%
# Save model
approximator.save("..\..\Results\model_comparison_MAMMALS_newPriors.keras")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Save model
# ----> 2 approximator.save("..\..\Results\model_comparison_MAMMALS_newPriors.keras")
#
# NameError: name 'approximator' is not defined

# %% [markdown]
# # 4 Model Fitting per Participant

# %%
# Load data
df = pd.read_csv('..\..\Data\data_analysis_mammals.csv', sep = ",")
df.head()
# Out:
#    ID_item             item     img  training  crit  chp46vl70814  \
# 0        1           Aoudad  01.png         0   335          2000
# 1        2  Brazilian tapir  02.png         0  1095           550
# 2        3   American bison  03.png         0   912          3000
# 3        4   Giant anteater  04.png         0  1186           750
# 4        5             Ibex  05.png         0   797           700
#
#    apzvrxiaap22  dp0g9nbjr8wo  ch1i36lf3gb1  mrb0s0ckbda9  ...  0xhc0yxm5czl  \
# 0          1500          1200           700           257  ...           600
# 1           500          1200           600           321  ...           800
# 2          2000          2500           360           875  ...          1500
# 3           250          1500           500           432  ...           500
# 4          2000           650           350           543  ...           640
#
#    uh7i5dewrmic  wl5925o0j4iv  a3eokjk1z75r  tk04u7pmrsvp  s2edlrqnhaz8  \
# 0          1350           750          2000           600           880
# 1           802           560           720           400           456
# 2          3520          1566          4000          1500           578
# 3           450           550           550           400           450
# 4          1256           720           720          2000           340
#
#    2qewr80masfh  xhkz4vsry78k  rsulb3mqq6p4  u13d9hi208ge
# 0           600           700           730           700
# 1           590           700          1100           700
# 2          1500          1300           678           570
# 3           900          1400           564           400
# 4          1500           800          1100           570
#
# [5 rows x 53 columns]

# %%
data            = df.to_numpy()
data            = np.float32(data[(test_IDs-1),5:])

n_trials, n_sub = data.shape

# %% [markdown]
# ## Plot data

# %%
# Plot prior predictives
fig, axes = plt.subplots(figsize=(10, 5))
dataset_colors = sns.color_palette("plasma", n_sub).as_hex()

for dataset in range(n_sub):
    color = dataset_colors[dataset]

    sns.kdeplot(data[:,dataset].squeeze(), ax=axes, alpha=0.3, legend=False, color=color,clip=(0.0, 10000.0))
    

axes.set_title("Prior Predictive: Guessing (for 100 Participants)")
# Out:
# Text(0.5, 1.0, 'Prior Predictive: Guessing (for 100 Participants)')

# %% [markdown]
# ## "Fit" Models

# %%
# Load model if needed
# approximator  = keras.saving.load_model("..\Results\model_comparison_MAMMALS.keras")
# Out:
# c:\Users\dizydorc\OneDrive\University\1 Projects\28 DFG Judgment Processes in Real-World Domains\.venv\Lib\site-packages\keras\src\saving\saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 1 variables whereas the saved optimizer has 105 variables.

# %%
n_models = 6    
all_pmps = np.zeros((n_sub, n_models)) 

for i in range(n_sub):
    pmp         = approximator.predict(conditions=dict(x=data[:,i], p = position_encodings))[0]
    all_pmps[i] = pmp.flatten()

# %%
# Store results
all_pmps_df  = pd.DataFrame(all_pmps)
all_pmps_df.columns = ["RULEXJ", "CAM", "GCM", "MAPP", "QEst", "RGuess"]


all_pmps_df.to_csv("..\..\Results\pmp_MAMMALS.csv")

# %%
model_labels = ["RULEXJ", "CAM", "GCM", "MAPP", "QEst", "RGuess"]

plt.figure(figsize=(4, 8))
im = plt.imshow(all_pmps, aspect='auto', cmap='plasma', vmin=0, vmax=1)  # Fix color range

# Add colorbar with defined ticks from 0 to 1
cbar = plt.colorbar(im)
cbar.set_label('Posterior Model Probability')
cbar.set_ticks([0, 0.25, 0.5, 0.75, 1.0])  # Explicit tick marks

plt.xlabel('Model')
plt.ylabel('Participant')
plt.title('Posterior Model Probabilities (PMPs)')

plt.xticks(ticks=np.arange(len(model_labels)), labels=model_labels, rotation=45);
plt.yticks(ticks=np.arange(n_sub), labels=[str(i) for i in range(n_sub)]);

plt.tight_layout()
plt.show()
